# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import panel
import random as rd

#random module, returns a single value, np random populate random numbers in an array
rd.random()
rd.choice(['evil','good','nice'])

np.random.rand(5,5)
np.random.choice(a=['dog','pig','bread'],size=(2,2))
#create a df with random values

fake = pd.DataFrame(np.random.rand(25,4), columns = ['length','width','height','speed'])
fake['label'] = np.random.choice(a=['pig', 'dog','bread'], size=(25,1))

# %%
#barchartax
ax = fake.plot(kind='bar',grid=True, stacked=True)
